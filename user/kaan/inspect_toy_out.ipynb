# %% [markdown]
# ### Generate Toys v2

# %%
import numpy as np
x = np.load("/scratch-cbe/users/alikaan.gueven/SBIPDF/output/toys/toy_0000.npz")
vars(x)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 import numpy as np
# ----> 2 x = np.load("/scratch-cbe/users/alikaan.gueven/SBIPDF/output/toys/toy_0000.npz")
#       3 vars(x)
#
# File /groups/hephy/cms/alikaan.gueven/conda/envs/SDV/lib/python3.11/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/scratch-cbe/users/alikaan.gueven/SBIPDF/output/toys/toy_0000.npz'

# %% [markdown]
# ### Generate Toys v3

# %%
import numpy as np
x = np.load("/scratch-cbe/users/alikaan.gueven/SBIPDF/output/toys/toys_c1_0.2_mode-poisson_N100.npz")
vars(x)
# Out:
# {'_files': ['toy0000_SR_indices.npy',
#   'toy0001_SR_indices.npy',
#   'toy0002_SR_indices.npy',
#   'toy0003_SR_indices.npy',
#   'toy0004_SR_indices.npy',
#   'toy0005_SR_indices.npy',
#   'toy0006_SR_indices.npy',
#   'toy0007_SR_indices.npy',
#   'toy0008_SR_indices.npy',
#   'toy0009_SR_indices.npy',
#   'toy0010_SR_indices.npy',
#   'toy0011_SR_indices.npy',
#   'toy0012_SR_indices.npy',
#   'toy0013_SR_indices.npy',
#   'toy0014_SR_indices.npy',
#   'toy0015_SR_indices.npy',
#   'toy0016_SR_indices.npy',
#   'toy0017_SR_indices.npy',
#   'toy0018_SR_indices.npy',
#   'toy0019_SR_indices.npy',
#   'toy0020_SR_indices.npy',
#   'toy0021_SR_indices.npy',
#   'toy0022_SR_indices.npy',
#   'toy0023_SR_indices.npy',
#   'toy0024_SR_indices.npy',
#   'toy0025_SR_indices.npy',
#   'toy0026_SR_indices.npy',
#   'toy0027_SR_indices.npy',
#   'toy0028_SR_indices.npy',
#   'toy0029_SR_indices.npy',
#   'toy0030_SR_indices.npy',
#   'toy0031_SR_indices.npy',
#   'toy0032_SR_indices.npy',
# ...

# %% [markdown]
# ### Check if rejection is possible or not

# %%
import numpy as np

# %%
x = [np.ones((1,2,3)), np.ones((1,2,3))]

# %%
np.concatenate(x, axis = -1).shape
# Out:
# (1, 2, 6)

# %%
import os

# %%
x = 1.3245424232

# %%
print(f"{x:.3g}")
# Out:
# 1.32

# %%
import numpy as np

x = np.load("/scratch-cbe/users/alikaan.gueven/SBIPDF/output/toys/toys_nominal_mode-poisson_N100.npz")

# %%
for k in x.keys():
    print(k)
# Out:
# toy0000_SR_indices
# toy0001_SR_indices
# toy0002_SR_indices
# toy0003_SR_indices
# toy0004_SR_indices
# toy0005_SR_indices
# toy0006_SR_indices
# toy0007_SR_indices
# toy0008_SR_indices
# toy0009_SR_indices
# toy0010_SR_indices
# toy0011_SR_indices
# toy0012_SR_indices
# toy0013_SR_indices
# toy0014_SR_indices
# toy0015_SR_indices
# toy0016_SR_indices
# toy0017_SR_indices
# toy0018_SR_indices
# toy0019_SR_indices
# toy0020_SR_indices
# toy0021_SR_indices
# toy0022_SR_indices
# toy0023_SR_indices
# toy0024_SR_indices
# toy0025_SR_indices
# toy0026_SR_indices
# toy0027_SR_indices
# toy0028_SR_indices
# toy0029_SR_indices
# toy0030_SR_indices
# toy0031_SR_indices
# toy0032_SR_indices
# toy0033_SR_indices
# toy0034_SR_indices
# toy0035_SR_indices
# toy0036_SR_indices
# toy0037_SR_indices
# toy0038_SR_indices
# toy0039_SR_indices
# toy0040_SR_indices
# toy0041_SR_indices
# toy0042_SR_indices
# toy0043_SR_indices
# toy0044_SR_indices
# toy0045_SR_indices
# toy0046_SR_indices
# ...
